# %%
# !pip install -q transformers==4.37.2 --quiet
# !pip install pydot --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 14.7 MB/s eta 0:00:00

# %%
from sklearn.model_selection import train_test_split
from collections import Counter
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from transformers import BertTokenizer, TFBertModel, AutoTokenizer, AutoModel
import torch
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/w266_project')
df = pd.read_csv("features.csv", header = 0, sep="\t", index_col=0)

# %%
# Load SciBERT tokenizer and model
model_checkpoint = "allenai/scibert_scivocab_uncased"
bert_tokenizer = BertTokenizer.from_pretrained(model_checkpoint)
bert_model = TFBertModel.from_pretrained(model_checkpoint, from_pt=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.txt:   0%|          | 0.00/228k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
X = df[['Year Published', 'Cited Reference Count', 'Page Count', 'num_auth', 'num_words', 'Funding','Auth_country', 'Pub_country', 'Abstract']]
y = df['JIF']

train_idx, val_idx, y_train, y_val = train_test_split(range(len(df)), y, test_size=0.3, random_state=42)

# %%
# Prepare categorical data
categories = ['Funding','Auth_country', 'Pub_country']
train_one_hot_data = {}
val_one_hot_data = {}
for cat in categories:
  one_hot_df = pd.get_dummies(df[cat], prefix=cat, dtype=int)
  train_one_hot_data[cat] = one_hot_df.iloc[train_idx]
  val_one_hot_data[cat] = one_hot_df.iloc[val_idx]

# Prepare numerical data
num_data = X[['Year Published', 'Cited Reference Count', 'Page Count', 'num_auth', 'num_words']]
scaler  = MinMaxScaler(feature_range=(0,1))
num_data = scaler.fit_transform(num_data)
train_num_data = num_data[train_idx]
val_num_data = num_data[val_idx]

# %% [markdown]
# ### Model with text and metadata

# %%
max_length = 400
train_encodings = bert_tokenizer(list(X['Abstract'].iloc[train_idx]), truncation=True, padding=True, max_length=max_length, return_tensors='tf')
val_encodings = bert_tokenizer(list(X['Abstract'].iloc[val_idx]), truncation=True, padding=True, max_length=max_length, return_tensors='tf')

# %%
hidden_size = 768 + 5 + 49 + 10 + 1
dropout = 0.3
bert_model.trainable = False
learning_rate = 0.0001

num_of_levels  = df['Funding'].nunique()
#Jeremy Howard provides the following rule of thumb; embedding size = min(50, number of categories/2).
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Funding embeding size: {embedding_size}')

fund_input = keras.layers.Input(shape=(num_of_levels,), name = 'fund_input')
fund_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'fund_emb')(fund_input)
fund_flat = keras.layers.Flatten(name = 'fund_flat')(fund_emb)

num_of_levels  = df['Auth_country'].nunique()
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Auth cont embeding size: {embedding_size}')

Auth_input = keras.layers.Input(shape=(num_of_levels,), name = 'Auth_input')
Auth_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'Auth_emb')(Auth_input)
Auth_flat = keras.layers.Flatten(name = 'Auth_flat')(Auth_emb)

num_of_levels  = df['Pub_country'].nunique()
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Pub cont embeding size: {embedding_size}')

Pub_input = keras.layers.Input(shape=(num_of_levels,), name = 'Pub_input')
Pub_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'Pub_emb')(Pub_input)
Pub_flat = keras.layers.Flatten(name = 'Pub_flat')(Pub_emb)

inp_num_data = keras.layers.Input(shape=(num_data.shape[1],), name = 'Num feat')

bert_model.trainable = False

input_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='input_ids_layer')
token_type_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='token_type_ids_layer')
attention_mask = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='attention_mask_layer')

bert_inputs = {'input_ids': input_ids,
                'token_type_ids': token_type_ids,
                'attention_mask': attention_mask}

bert_out = bert_model(bert_inputs)

token = bert_out[0][:, 0, :] #cls token

# Concatenate all layers
conc = keras.layers.Concatenate()([token, Auth_flat, Pub_flat, fund_flat, inp_num_data])

hidden1 = tf.keras.layers.Dense(hidden_size, activation='relu', name='hidden_layer1')(conc)
hidden1 = tf.keras.layers.Dropout(dropout)(hidden1)

# Create output layer
out = keras.layers.Dense(1, activation='linear', name = 'Regression_layer')(hidden1)
model = keras.Model(inputs=[input_ids, token_type_ids, attention_mask,
                            Auth_input, Pub_input, fund_input,
                            inp_num_data], outputs=out)


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
              loss=keras.losses.mean_squared_error,
              metrics=[keras.metrics.mean_squared_error])
# Out:
# Funding embeding size: 1
# Auth cont embeding size: 49
# Pub cont embeding size: 9

# %%
#Set up early stopping monitor
early_stopping = EarlyStopping(monitor='val_mean_squared_error',
                               patience=5,
                               mode = "auto",
                               restore_best_weights=True)

model.fit([ train_encodings.input_ids, train_encodings.token_type_ids, train_encodings.attention_mask,
           train_one_hot_data['Auth_country'], train_one_hot_data['Pub_country'], train_one_hot_data['Funding'],
           train_num_data],
           y_train,
           validation_data=([val_encodings.input_ids, val_encodings.token_type_ids, val_encodings.attention_mask,
                            val_one_hot_data['Auth_country'], val_one_hot_data['Pub_country'], val_one_hot_data['Funding'],
                            val_num_data],
                            y_val),
           batch_size=8, epochs=60, callbacks=[early_stopping])
# Out:
# Epoch 1/60
# 388/388 [==============================] - 81s 159ms/step - loss: 3.9135 - mean_squared_error: 3.9135 - val_loss: 3.3089 - val_mean_squared_error: 3.3089
# Epoch 2/60
# 388/388 [==============================] - 63s 164ms/step - loss: 3.2623 - mean_squared_error: 3.2623 - val_loss: 3.2864 - val_mean_squared_error: 3.2864
# Epoch 3/60
# 388/388 [==============================] - 63s 163ms/step - loss: 3.2038 - mean_squared_error: 3.2038 - val_loss: 3.0858 - val_mean_squared_error: 3.0858
# Epoch 4/60
# 388/388 [==============================] - 63s 163ms/step - loss: 3.1026 - mean_squared_error: 3.1026 - val_loss: 3.1196 - val_mean_squared_error: 3.1196
# Epoch 5/60
# 388/388 [==============================] - 63s 163ms/step - loss: 2.9521 - mean_squared_error: 2.9521 - val_loss: 2.9699 - val_mean_squared_error: 2.9699
# Epoch 6/60
# 388/388 [==============================] - 63s 162ms/step - loss: 2.8909 - mean_squared_error: 2.8909 - val_loss: 3.0247 - val_mean_squared_error: 3.0247
# Epoch 7/60
# 388/388 [==============================] - 58s 150ms/step - loss: 2.8227 - mean_squared_error: 2.8227 - val_loss: 2.9583 - val_mean_squared_error: 2.9583
# Epoch 8/60
# 388/388 [==============================] - 63s 162ms/step - loss: 2.7409 - mean_squared_error: 2.7409 - val_loss: 3.4692 - val_mean_squared_error: 3.4692
# Epoch 9/60
# 388/388 [==============================] - 64s 164ms/step - loss: 2.7157 - mean_squared_error: 2.7157 - val_loss: 2.8576 - val_mean_squared_error: 2.8576
# Epoch 10/60
# 388/388 [==============================] - 59s 151ms/step - loss: 2.5944 - mean_squared_error: 2.5944 - val_loss: 2.8519 - val_mean_squared_error: 2.8519
# Epoch 11/60
# 388/388 [==============================] - 63s 162ms/step - loss: 2.5826 - mean_squared_error: 2.5826 - val_loss: 2.8527 - val_mean_squared_error: 2.8527
# Epoch 12/60
# 388/388 [==============================] - 59s 152ms/step - loss: 2.4692 - mean_squared_error: 2.4692 - val_loss: 2.7209 - val_mean_squared_error: 2.7209
# Epoch 13/60
# 388/388 [==============================] - 63s 163ms/step - loss: 2.4148 - mean_squared_error: 2.4148 - val_loss: 2.7674 - val_mean_squared_error: 2.7674
# Epoch 14/60
# 388/388 [==============================] - 63s 162ms/step - loss: 2.4702 - mean_squared_error: 2.4702 - val_loss: 2.8839 - val_mean_squared_error: 2.8839
# Epoch 15/60
# 388/388 [==============================] - 57s 148ms/step - loss: 2.3674 - mean_squared_error: 2.3674 - val_loss: 2.6923 - val_mean_squared_error: 2.6923
# Epoch 16/60
# 388/388 [==============================] - 62s 161ms/step - loss: 2.2562 - mean_squared_error: 2.2562 - val_loss: 2.7282 - val_mean_squared_error: 2.7282
# Epoch 17/60
# 388/388 [==============================] - 58s 150ms/step - loss: 2.2897 - mean_squared_error: 2.2897 - val_loss: 2.6827 - val_mean_squared_error: 2.6827
# Epoch 18/60
# 388/388 [==============================] - 64s 164ms/step - loss: 2.1511 - mean_squared_error: 2.1511 - val_loss: 2.6445 - val_mean_squared_error: 2.6445
# Epoch 19/60
# 388/388 [==============================] - 63s 162ms/step - loss: 2.0991 - mean_squared_error: 2.0991 - val_loss: 2.6855 - val_mean_squared_error: 2.6855
# Epoch 20/60
# 388/388 [==============================] - 63s 162ms/step - loss: 2.0213 - mean_squared_error: 2.0213 - val_loss: 2.6041 - val_mean_squared_error: 2.6041
# Epoch 21/60
# 388/388 [==============================] - 63s 162ms/step - loss: 2.0058 - mean_squared_error: 2.0058 - val_loss: 2.5651 - val_mean_squared_error: 2.5651
# Epoch 22/60
# 388/388 [==============================] - 63s 161ms/step - loss: 1.9752 - mean_squared_error: 1.9752 - val_loss: 2.6292 - val_mean_squared_error: 2.6292
# Epoch 23/60
# 388/388 [==============================] - 63s 163ms/step - loss: 2.0260 - mean_squared_error: 2.0260 - val_loss: 2.8009 - val_mean_squared_error: 2.8009
# Epoch 24/60
# 388/388 [==============================] - 63s 163ms/step - loss: 1.8974 - mean_squared_error: 1.8974 - val_loss: 2.6371 - val_mean_squared_error: 2.6371
# Epoch 25/60
# 388/388 [==============================] - 63s 163ms/step - loss: 1.8939 - mean_squared_error: 1.8939 - val_loss: 2.6686 - val_mean_squared_error: 2.6686
# Epoch 26/60
# 388/388 [==============================] - 63s 164ms/step - loss: 1.7721 - mean_squared_error: 1.7721 - val_loss: 2.6288 - val_mean_squared_error: 2.6288

# %%
pred = model.predict([val_encodings.input_ids, val_encodings.token_type_ids, val_encodings.attention_mask,
                      val_one_hot_data['Auth_country'], val_one_hot_data['Pub_country'], val_one_hot_data['Funding'],
                      val_num_data])
# Out:
# 42/42 [==============================] - 17s 295ms/step

# %%
predictions = pred.reshape((-1))
fig, ax = plt.subplots()
ax.hist2d(predictions, y_val , bins=(np.arange(0, 14, 0.2), np.arange(0, 14, 0.2)))
ax.set_title('sciBERT with metadata')
ax.set_xlabel('Predicted')
ax.set_ylabel('Observed')
# Out:
# Text(0, 0.5, 'Observed')

# %%
np.corrcoef(predictions, y_val)
# Out:
# array([[1.        , 0.67344503],
#        [0.67344503, 1.        ]])

# %%
df_to_save = pd.DataFrame({'Observed':y_val, 'Predicted':predictions})
df_to_save.to_csv('scibert_meta.csv', '\t')

# %% [markdown]
# ### Model with no text, only metadata

# %%
hidden_size = 768 + 5 + 49 + 10 + 1
dropout = 0.3
bert_model.trainable = False
learning_rate = 0.0001

num_of_levels  = df['Funding'].nunique()
#Jeremy Howard provides the following rule of thumb; embedding size = min(50, number of categories/2).
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Funding embeding size: {embedding_size}')

fund_input = keras.layers.Input(shape=(num_of_levels,), name = 'fund_input')
fund_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'fund_emb')(fund_input)
fund_flat = keras.layers.Flatten(name = 'fund_flat')(fund_emb)

num_of_levels  = df['Auth_country'].nunique()
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Auth cont embeding size: {embedding_size}')

Auth_input = keras.layers.Input(shape=(num_of_levels,), name = 'Auth_input')
Auth_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'Auth_emb')(Auth_input)
Auth_flat = keras.layers.Flatten(name = 'Auth_flat')(Auth_emb)

num_of_levels  = df['Pub_country'].nunique()
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Pub cont embeding size: {embedding_size}')

Pub_input = keras.layers.Input(shape=(num_of_levels,), name = 'Pub_input')
Pub_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'Pub_emb')(Pub_input)
Pub_flat = keras.layers.Flatten(name = 'Pub_flat')(Pub_emb)

inp_num_data = keras.layers.Input(shape=(num_data.shape[1],), name = 'Num feat')

# Concatenate all layers
conc = keras.layers.Concatenate()([Auth_flat, Pub_flat, fund_flat, inp_num_data])

hidden1 = tf.keras.layers.Dense(hidden_size, activation='relu', name='hidden_layer1')(conc)
hidden1 = tf.keras.layers.Dropout(dropout)(hidden1)

# Create output layer
out = keras.layers.Dense(1, activation='linear', name = 'Regression_layer')(hidden1)

#Create and compile the model
model_notext = keras.Model(inputs=[Auth_input, Pub_input, fund_input, inp_num_data], outputs=out)
model_notext.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
              loss=keras.losses.mean_squared_error,
              metrics=[keras.metrics.mean_squared_error])
# Out:
# Funding embeding size: 1
# Auth cont embeding size: 49
# Pub cont embeding size: 9

# %%
#Set up early stopping monitor
early_stopping = EarlyStopping(monitor='val_mean_squared_error',
                               patience=5,
                               mode = "auto",
                               restore_best_weights=True)

model_notext.fit([ train_one_hot_data['Auth_country'], train_one_hot_data['Pub_country'], train_one_hot_data['Funding'], train_num_data],
           y_train,
           validation_data=([val_one_hot_data['Auth_country'], val_one_hot_data['Pub_country'], val_one_hot_data['Funding'], val_num_data],
                            y_val),
           batch_size=8, epochs=60, callbacks=[early_stopping])
# Out:
# Epoch 1/60
# 388/388 [==============================] - 5s 10ms/step - loss: 5.1923 - mean_squared_error: 5.1923 - val_loss: 4.5367 - val_mean_squared_error: 4.5367
# Epoch 2/60
# 388/388 [==============================] - 2s 5ms/step - loss: 4.5645 - mean_squared_error: 4.5645 - val_loss: 4.3440 - val_mean_squared_error: 4.3440
# Epoch 3/60
# 388/388 [==============================] - 2s 5ms/step - loss: 4.3493 - mean_squared_error: 4.3493 - val_loss: 4.2123 - val_mean_squared_error: 4.2123
# Epoch 4/60
# 388/388 [==============================] - 2s 5ms/step - loss: 4.1432 - mean_squared_error: 4.1432 - val_loss: 4.0024 - val_mean_squared_error: 4.0024
# Epoch 5/60
# 388/388 [==============================] - 2s 5ms/step - loss: 4.0178 - mean_squared_error: 4.0178 - val_loss: 3.8605 - val_mean_squared_error: 3.8605
# Epoch 6/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.9110 - mean_squared_error: 3.9110 - val_loss: 3.7727 - val_mean_squared_error: 3.7727
# Epoch 7/60
# 388/388 [==============================] - 3s 8ms/step - loss: 3.8594 - mean_squared_error: 3.8594 - val_loss: 3.7241 - val_mean_squared_error: 3.7241
# Epoch 8/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.7841 - mean_squared_error: 3.7841 - val_loss: 3.6574 - val_mean_squared_error: 3.6574
# Epoch 9/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.7214 - mean_squared_error: 3.7214 - val_loss: 3.6221 - val_mean_squared_error: 3.6221
# Epoch 10/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.7156 - mean_squared_error: 3.7156 - val_loss: 3.5879 - val_mean_squared_error: 3.5879
# Epoch 11/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.6678 - mean_squared_error: 3.6678 - val_loss: 3.5553 - val_mean_squared_error: 3.5553
# Epoch 12/60
# 388/388 [==============================] - 3s 7ms/step - loss: 3.5971 - mean_squared_error: 3.5971 - val_loss: 3.5464 - val_mean_squared_error: 3.5464
# Epoch 13/60
# 388/388 [==============================] - 3s 7ms/step - loss: 3.5931 - mean_squared_error: 3.5931 - val_loss: 3.5306 - val_mean_squared_error: 3.5306
# Epoch 14/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.5588 - mean_squared_error: 3.5588 - val_loss: 3.6540 - val_mean_squared_error: 3.6540
# Epoch 15/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.5418 - mean_squared_error: 3.5418 - val_loss: 3.4821 - val_mean_squared_error: 3.4821
# Epoch 16/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.5059 - mean_squared_error: 3.5059 - val_loss: 3.4825 - val_mean_squared_error: 3.4825
# Epoch 17/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.5002 - mean_squared_error: 3.5002 - val_loss: 3.5140 - val_mean_squared_error: 3.5140
# Epoch 18/60
# 388/388 [==============================] - 3s 8ms/step - loss: 3.4859 - mean_squared_error: 3.4859 - val_loss: 3.4434 - val_mean_squared_error: 3.4434
# Epoch 19/60
# 388/388 [==============================] - 3s 7ms/step - loss: 3.4625 - mean_squared_error: 3.4625 - val_loss: 3.4362 - val_mean_squared_error: 3.4362
# Epoch 20/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.4080 - mean_squared_error: 3.4080 - val_loss: 3.4285 - val_mean_squared_error: 3.4285
# Epoch 21/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.4039 - mean_squared_error: 3.4039 - val_loss: 3.5770 - val_mean_squared_error: 3.5770
# Epoch 22/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.4253 - mean_squared_error: 3.4253 - val_loss: 3.4768 - val_mean_squared_error: 3.4768
# Epoch 23/60
# 388/388 [==============================] - 3s 8ms/step - loss: 3.4060 - mean_squared_error: 3.4060 - val_loss: 3.4452 - val_mean_squared_error: 3.4452
# Epoch 24/60
# 388/388 [==============================] - 3s 8ms/step - loss: 3.3512 - mean_squared_error: 3.3512 - val_loss: 3.3965 - val_mean_squared_error: 3.3965
# Epoch 25/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.3279 - mean_squared_error: 3.3279 - val_loss: 3.4109 - val_mean_squared_error: 3.4109
# Epoch 26/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.3426 - mean_squared_error: 3.3426 - val_loss: 3.4443 - val_mean_squared_error: 3.4443
# Epoch 27/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.3177 - mean_squared_error: 3.3177 - val_loss: 3.3784 - val_mean_squared_error: 3.3784
# Epoch 28/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.3039 - mean_squared_error: 3.3039 - val_loss: 3.3669 - val_mean_squared_error: 3.3669
# Epoch 29/60
# 388/388 [==============================] - 3s 8ms/step - loss: 3.2932 - mean_squared_error: 3.2932 - val_loss: 3.3724 - val_mean_squared_error: 3.3724
# Epoch 30/60
# 388/388 [==============================] - 3s 7ms/step - loss: 3.2699 - mean_squared_error: 3.2699 - val_loss: 3.3658 - val_mean_squared_error: 3.3658
# Epoch 31/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.2479 - mean_squared_error: 3.2479 - val_loss: 3.3864 - val_mean_squared_error: 3.3864
# Epoch 32/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.2614 - mean_squared_error: 3.2614 - val_loss: 3.4325 - val_mean_squared_error: 3.4325
# Epoch 33/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.2690 - mean_squared_error: 3.2690 - val_loss: 3.3564 - val_mean_squared_error: 3.3564
# Epoch 34/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.2382 - mean_squared_error: 3.2382 - val_loss: 3.3784 - val_mean_squared_error: 3.3784
# Epoch 35/60
# 388/388 [==============================] - 3s 9ms/step - loss: 3.2187 - mean_squared_error: 3.2187 - val_loss: 3.3614 - val_mean_squared_error: 3.3614
# Epoch 36/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.2308 - mean_squared_error: 3.2308 - val_loss: 3.3541 - val_mean_squared_error: 3.3541
# Epoch 37/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.2277 - mean_squared_error: 3.2277 - val_loss: 3.3333 - val_mean_squared_error: 3.3333
# Epoch 38/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.2291 - mean_squared_error: 3.2291 - val_loss: 3.3371 - val_mean_squared_error: 3.3371
# Epoch 39/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.2129 - mean_squared_error: 3.2129 - val_loss: 3.3286 - val_mean_squared_error: 3.3286
# Epoch 40/60
# 388/388 [==============================] - 4s 11ms/step - loss: 3.2090 - mean_squared_error: 3.2090 - val_loss: 3.3246 - val_mean_squared_error: 3.3246
# Epoch 41/60
# 388/388 [==============================] - 3s 7ms/step - loss: 3.1861 - mean_squared_error: 3.1861 - val_loss: 3.3165 - val_mean_squared_error: 3.3165
# Epoch 42/60
# 388/388 [==============================] - 4s 10ms/step - loss: 3.1458 - mean_squared_error: 3.1458 - val_loss: 3.3241 - val_mean_squared_error: 3.3241
# Epoch 43/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.1901 - mean_squared_error: 3.1901 - val_loss: 3.3221 - val_mean_squared_error: 3.3221
# Epoch 44/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.1793 - mean_squared_error: 3.1793 - val_loss: 3.3069 - val_mean_squared_error: 3.3069
# Epoch 45/60
# 388/388 [==============================] - 3s 9ms/step - loss: 3.1445 - mean_squared_error: 3.1445 - val_loss: 3.3088 - val_mean_squared_error: 3.3088
# Epoch 46/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.1617 - mean_squared_error: 3.1617 - val_loss: 3.3022 - val_mean_squared_error: 3.3022
# Epoch 47/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.1399 - mean_squared_error: 3.1399 - val_loss: 3.3436 - val_mean_squared_error: 3.3436
# Epoch 48/60
# 388/388 [==============================] - 3s 6ms/step - loss: 3.1409 - mean_squared_error: 3.1409 - val_loss: 3.2991 - val_mean_squared_error: 3.2991
# Epoch 49/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.1250 - mean_squared_error: 3.1250 - val_loss: 3.3411 - val_mean_squared_error: 3.3411
# Epoch 50/60
# 388/388 [==============================] - 3s 9ms/step - loss: 3.1378 - mean_squared_error: 3.1378 - val_loss: 3.2874 - val_mean_squared_error: 3.2874
# Epoch 51/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.1160 - mean_squared_error: 3.1160 - val_loss: 3.3563 - val_mean_squared_error: 3.3563
# Epoch 52/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.1229 - mean_squared_error: 3.1229 - val_loss: 3.2879 - val_mean_squared_error: 3.2879
# Epoch 53/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.1241 - mean_squared_error: 3.1241 - val_loss: 3.2868 - val_mean_squared_error: 3.2868
# Epoch 54/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.1056 - mean_squared_error: 3.1056 - val_loss: 3.2863 - val_mean_squared_error: 3.2863
# Epoch 55/60
# 388/388 [==============================] - 3s 6ms/step - loss: 3.0916 - mean_squared_error: 3.0916 - val_loss: 3.3022 - val_mean_squared_error: 3.3022
# Epoch 56/60
# 388/388 [==============================] - 3s 9ms/step - loss: 3.0869 - mean_squared_error: 3.0869 - val_loss: 3.2866 - val_mean_squared_error: 3.2866
# Epoch 57/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.1156 - mean_squared_error: 3.1156 - val_loss: 3.3384 - val_mean_squared_error: 3.3384
# Epoch 58/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.1142 - mean_squared_error: 3.1142 - val_loss: 3.2817 - val_mean_squared_error: 3.2817
# Epoch 59/60
# 388/388 [==============================] - 2s 6ms/step - loss: 3.0963 - mean_squared_error: 3.0963 - val_loss: 3.2781 - val_mean_squared_error: 3.2781
# Epoch 60/60
# 388/388 [==============================] - 2s 5ms/step - loss: 3.1131 - mean_squared_error: 3.1131 - val_loss: 3.2794 - val_mean_squared_error: 3.2794

# %%
pred_notext = model_notext.predict([val_one_hot_data['Auth_country'], val_one_hot_data['Pub_country'], val_one_hot_data['Funding'], val_num_data])
# Out:
# 42/42 [==============================] - 0s 2ms/step

# %%
predictions = pred_notext.reshape((-1))
fig, ax = plt.subplots()
ax.hist2d(predictions, y_val , bins=(np.arange(0, 14, 0.2), np.arange(0, 14, 0.2)))
ax.set_title('Metadata only')
ax.set_xlabel('Predicted')
ax.set_ylabel('Observed')

# %%
np.corrcoef(predictions, y_val)

# %%
df_to_save = pd.DataFrame({'Observed':y_val, 'Predicted':predictions})
df_to_save.to_csv('meta_only.csv', '\t')
