# %%
# !pip install -q transformers==4.37.2 --quiet
# !pip install pydot --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 53.5 MB/s eta 0:00:00

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import numpy as np


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
from keras.callbacks import EarlyStopping

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from transformers import BertTokenizer, TFBertModel, AutoTokenizer, AutoModel

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/w266_project')
df = pd.read_csv("features.csv", header = 0, sep="\t", index_col=0)

# %%
# Load SciBERT tokenizer and model
model_checkpoint = "allenai/scibert_scivocab_uncased"
bert_tokenizer = BertTokenizer.from_pretrained(model_checkpoint)
bert_model = TFBertModel.from_pretrained(model_checkpoint, from_pt=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
big_countries = ['USA', 'Germany' 'Japan', 'Sweden', 'UK', 'Canada', 'Italy', 'Switzerland', 'France', 'China', 'Belgium', 'Netherlands', 'Australia', 'Spain',
'Poland', 'Austria', 'Denmark', 'Hungary','India','Finland','Taiwan', 'South Korea','Russia' ,'Czech Rep.']

df['Auth_country'] = df['Auth_country'].apply(lambda x: x if x in big_countries else 'other')

# %%
df['Abstract'] = df['Document Title'] + df['Abstract']

# %%
X = df[['Year Published', 'Cited Reference Count', 'Page Count', 'num_auth', 'num_words', 'Funding','Auth_country', 'Pub_country', 'Abstract']]
y = df['JIF']

train_idx, val_idx, y_train, y_val = train_test_split(range(len(df)), y, test_size=0.3, random_state=42)

# %%
# Prepare categorical data
categories = ['Funding','Auth_country', 'Pub_country']
train_one_hot_data = {}
val_one_hot_data = {}
for cat in categories:
  one_hot_df = pd.get_dummies(df[cat], prefix=cat, dtype=int)
  train_one_hot_data[cat] = one_hot_df.iloc[train_idx]
  val_one_hot_data[cat] = one_hot_df.iloc[val_idx]

# Prepare numerical data
num_data = X[['Year Published', 'Cited Reference Count', 'Page Count', 'num_auth', 'num_words']]
scaler  = MinMaxScaler(feature_range=(0,1))
num_data = scaler.fit_transform(num_data)
train_num_data = num_data[train_idx]
val_num_data = num_data[val_idx]

# %% [markdown]
# ### Model with text and metadata

# %%
max_length = 400
train_encodings = bert_tokenizer(list(X['Abstract'].iloc[train_idx]), truncation=True, padding=True, max_length=max_length, return_tensors='tf')
val_encodings = bert_tokenizer(list(X['Abstract'].iloc[val_idx]), truncation=True, padding=True, max_length=max_length, return_tensors='tf')

# %%
hidden_size = 768 + 5 + 49 + 10 + 1
dropout = 0.3
learning_rate = 0.0001

num_of_levels  = df['Funding'].nunique()
#Jeremy Howard provides the following rule of thumb; embedding size = min(50, number of categories/2).
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Funding embeding size: {embedding_size}')

fund_input = keras.layers.Input(shape=(num_of_levels,), name = 'fund_input')
fund_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'fund_emb')(fund_input)
fund_flat = keras.layers.Flatten(name = 'fund_flat')(fund_emb)
fund_flat = tf.keras.layers.Dropout(dropout)(fund_flat)

num_of_levels  = df['Auth_country'].nunique()
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Auth cont embeding size: {embedding_size}')

Auth_input = keras.layers.Input(shape=(num_of_levels,), name = 'Auth_input')
Auth_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'Auth_emb')(Auth_input)
Auth_flat = keras.layers.Flatten(name = 'Auth_flat')(Auth_emb)
Auth_flat = tf.keras.layers.Dropout(dropout)(Auth_flat)

num_of_levels  = df['Pub_country'].nunique()
embedding_size = min(np.ceil((num_of_levels)/2), 50 )
embedding_size = int(embedding_size)
print(f'Pub cont embeding size: {embedding_size}')

Pub_input = keras.layers.Input(shape=(num_of_levels,), name = 'Pub_input')
Pub_emb = keras.layers.Embedding(input_dim=num_of_levels, output_dim=embedding_size, name = 'Pub_emb')(Pub_input)
Pub_flat = keras.layers.Flatten(name = 'Pub_flat')(Pub_emb)
Pub_flat = tf.keras.layers.Dropout(dropout)(Pub_flat)

inp_num_data = keras.layers.Input(shape=(num_data.shape[1],), name = 'Num feat')

#Set up the BERT part of the model
bert_model.trainable = False
# BERT inputs
input_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='input_ids_layer')
token_type_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='token_type_ids_layer')
attention_mask = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='attention_mask_layer')
bert_inputs = {'input_ids': input_ids,
                'token_type_ids': token_type_ids,
                'attention_mask': attention_mask}
bert_out = bert_model(bert_inputs)
tokens = bert_out[0][:,0,:] #cls token

# Concatenate all layers
conc = keras.layers.Concatenate()([tokens, Auth_flat, Pub_flat, fund_flat, inp_num_data])

hidden1 = tf.keras.layers.Dense(hidden_size, activation='relu', name='hidden_layer1')(conc)
hidden1 = tf.keras.layers.Dropout(dropout)(hidden1)

# Create output layer
out = keras.layers.Dense(1, activation='linear', name = 'Regression_layer')(hidden1)
model = keras.Model(inputs=[input_ids, token_type_ids, attention_mask,
                            Auth_input, Pub_input, fund_input,
                            inp_num_data], outputs=out)


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
              loss=keras.losses.mean_squared_error,
              metrics=[keras.metrics.mean_squared_error])
# Out:
# Funding embeding size: 1
# Auth cont embeding size: 12
# Pub cont embeding size: 10

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Auth_input (InputLayer)     [(None, 23)]                 0         []
#
#  Pub_input (InputLayer)      [(None, 20)]                 0         []
#
#  fund_input (InputLayer)     [(None, 2)]                  0         []
#
#  attention_mask_layer (Inpu  [(None, 400)]                0         []
#  tLayer)
#
#  input_ids_layer (InputLaye  [(None, 400)]                0         []
#  r)
#
#  token_type_ids_layer (Inpu  [(None, 400)]                0         []
#  tLayer)
#
#  Auth_emb (Embedding)        (None, 23, 12)               276       ['Auth_input[0][0]']
#
#  Pub_emb (Embedding)         (None, 20, 10)               200       ['Pub_input[0][0]']
#
#  fund_emb (Embedding)        (None, 2, 1)                 2         ['fund_input[0][0]']
#
#  tf_bert_model (TFBertModel  TFBaseModelOutputWithPooli   1099184   ['attention_mask_layer[0][0]',
#  )                           ngAndCrossAttentions(last_   64         'input_ids_layer[0][0]',
#                              hidden_state=(None, 400, 7              'token_type_ids_layer[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  Auth_flat (Flatten)         (None, 276)                  0         ['Auth_emb[0][0]']
#
#  Pub_flat (Flatten)          (None, 200)                  0         ['Pub_emb[0][0]']
#
#  fund_flat (Flatten)         (None, 2)                    0         ['fund_emb[0][0]']
#
#  tf.__operators__.getitem (  (None, 768)                  0         ['tf_bert_model[0][0]']
#  SlicingOpLambda)
#
#  dropout_38 (Dropout)        (None, 276)                  0         ['Auth_flat[0][0]']
#
#  dropout_39 (Dropout)        (None, 200)                  0         ['Pub_flat[0][0]']
#
#  dropout_37 (Dropout)        (None, 2)                    0         ['fund_flat[0][0]']
#
#  Num feat (InputLayer)       [(None, 5)]                  0         []
#
#  concatenate (Concatenate)   (None, 1251)                 0         ['tf.__operators__.getitem[0][
#                                                                     0]',
#                                                                      'dropout_38[0][0]',
#                                                                      'dropout_39[0][0]',
#                                                                      'dropout_37[0][0]',
#                                                                      'Num feat[0][0]']
#
#  hidden_layer1 (Dense)       (None, 833)                  1042916   ['concatenate[0][0]']
#
#  dropout_40 (Dropout)        (None, 833)                  0         ['hidden_layer1[0][0]']
#
#  Regression_layer (Dense)    (None, 1)                    834       ['dropout_40[0][0]']
#
# ==================================================================================================
# Total params: 110962692 (423.29 MB)
# Trainable params: 1044228 (3.98 MB)
# Non-trainable params: 109918464 (419.31 MB)
# __________________________________________________________________________________________________

# %%
#Set up early stopping monitor
early_stopping = EarlyStopping(monitor='val_mean_squared_error',
                               patience=5,
                               mode = "auto",
                               restore_best_weights=True)

model.fit([ train_encodings.input_ids, train_encodings.token_type_ids, train_encodings.attention_mask,
           train_one_hot_data['Auth_country'], train_one_hot_data['Pub_country'], train_one_hot_data['Funding'],
           train_num_data],
           y_train,
           validation_data=([val_encodings.input_ids, val_encodings.token_type_ids, val_encodings.attention_mask,
                            val_one_hot_data['Auth_country'], val_one_hot_data['Pub_country'], val_one_hot_data['Funding'],
                            val_num_data],
                            y_val),
           batch_size=128, epochs=60, callbacks=[early_stopping])
# Out:
# Epoch 1/60
# 25/25 [==============================] - 59s 2s/step - loss: 10.3939 - mean_squared_error: 10.3939 - val_loss: 5.0452 - val_mean_squared_error: 5.0452
# Epoch 2/60
# 25/25 [==============================] - 42s 2s/step - loss: 4.4371 - mean_squared_error: 4.4371 - val_loss: 3.9592 - val_mean_squared_error: 3.9592
# Epoch 3/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.9361 - mean_squared_error: 3.9361 - val_loss: 3.6616 - val_mean_squared_error: 3.6616
# Epoch 4/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.7253 - mean_squared_error: 3.7253 - val_loss: 3.5061 - val_mean_squared_error: 3.5061
# Epoch 5/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.5886 - mean_squared_error: 3.5886 - val_loss: 3.4145 - val_mean_squared_error: 3.4145
# Epoch 6/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.5181 - mean_squared_error: 3.5181 - val_loss: 3.3424 - val_mean_squared_error: 3.3424
# Epoch 7/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.4691 - mean_squared_error: 3.4691 - val_loss: 3.2929 - val_mean_squared_error: 3.2929
# Epoch 8/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.4474 - mean_squared_error: 3.4474 - val_loss: 3.2336 - val_mean_squared_error: 3.2336
# Epoch 9/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.3471 - mean_squared_error: 3.3471 - val_loss: 3.2520 - val_mean_squared_error: 3.2520
# Epoch 10/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.2461 - mean_squared_error: 3.2461 - val_loss: 3.2099 - val_mean_squared_error: 3.2099
# Epoch 11/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.1877 - mean_squared_error: 3.1877 - val_loss: 3.1611 - val_mean_squared_error: 3.1611
# Epoch 12/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.1505 - mean_squared_error: 3.1505 - val_loss: 3.1244 - val_mean_squared_error: 3.1244
# Epoch 13/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.0937 - mean_squared_error: 3.0937 - val_loss: 3.1318 - val_mean_squared_error: 3.1318
# Epoch 14/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.1404 - mean_squared_error: 3.1404 - val_loss: 3.0902 - val_mean_squared_error: 3.0902
# Epoch 15/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.0641 - mean_squared_error: 3.0641 - val_loss: 3.0692 - val_mean_squared_error: 3.0692
# Epoch 16/60
# 25/25 [==============================] - 42s 2s/step - loss: 3.0263 - mean_squared_error: 3.0263 - val_loss: 3.0254 - val_mean_squared_error: 3.0254
# Epoch 17/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.9190 - mean_squared_error: 2.9190 - val_loss: 3.0308 - val_mean_squared_error: 3.0308
# Epoch 18/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.9942 - mean_squared_error: 2.9942 - val_loss: 3.0134 - val_mean_squared_error: 3.0134
# Epoch 19/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.9275 - mean_squared_error: 2.9275 - val_loss: 2.9726 - val_mean_squared_error: 2.9726
# Epoch 20/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.9071 - mean_squared_error: 2.9071 - val_loss: 2.9651 - val_mean_squared_error: 2.9651
# Epoch 21/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.8490 - mean_squared_error: 2.8490 - val_loss: 2.9615 - val_mean_squared_error: 2.9615
# Epoch 22/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.9065 - mean_squared_error: 2.9065 - val_loss: 2.9037 - val_mean_squared_error: 2.9037
# Epoch 23/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.8406 - mean_squared_error: 2.8406 - val_loss: 2.9411 - val_mean_squared_error: 2.9411
# Epoch 24/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.7059 - mean_squared_error: 2.7059 - val_loss: 2.8942 - val_mean_squared_error: 2.8942
# Epoch 25/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.7413 - mean_squared_error: 2.7413 - val_loss: 2.8655 - val_mean_squared_error: 2.8655
# Epoch 26/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.7329 - mean_squared_error: 2.7329 - val_loss: 2.8744 - val_mean_squared_error: 2.8744
# Epoch 27/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.6571 - mean_squared_error: 2.6571 - val_loss: 2.8546 - val_mean_squared_error: 2.8546
# Epoch 28/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.6716 - mean_squared_error: 2.6716 - val_loss: 2.8685 - val_mean_squared_error: 2.8685
# Epoch 29/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.6321 - mean_squared_error: 2.6321 - val_loss: 2.8480 - val_mean_squared_error: 2.8480
# Epoch 30/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.6120 - mean_squared_error: 2.6120 - val_loss: 2.8943 - val_mean_squared_error: 2.8943
# Epoch 31/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.5949 - mean_squared_error: 2.5949 - val_loss: 2.8074 - val_mean_squared_error: 2.8074
# Epoch 32/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.5928 - mean_squared_error: 2.5928 - val_loss: 2.9953 - val_mean_squared_error: 2.9953
# Epoch 33/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.5414 - mean_squared_error: 2.5414 - val_loss: 2.7962 - val_mean_squared_error: 2.7962
# Epoch 34/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.5442 - mean_squared_error: 2.5442 - val_loss: 2.7838 - val_mean_squared_error: 2.7838
# Epoch 35/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.4717 - mean_squared_error: 2.4717 - val_loss: 2.8174 - val_mean_squared_error: 2.8174
# Epoch 36/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.4884 - mean_squared_error: 2.4884 - val_loss: 2.7858 - val_mean_squared_error: 2.7858
# Epoch 37/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.4252 - mean_squared_error: 2.4252 - val_loss: 2.7819 - val_mean_squared_error: 2.7819
# Epoch 38/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.3923 - mean_squared_error: 2.3923 - val_loss: 2.7479 - val_mean_squared_error: 2.7479
# Epoch 39/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.4343 - mean_squared_error: 2.4343 - val_loss: 2.7693 - val_mean_squared_error: 2.7693
# Epoch 40/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.3818 - mean_squared_error: 2.3818 - val_loss: 2.7390 - val_mean_squared_error: 2.7390
# Epoch 41/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.3322 - mean_squared_error: 2.3322 - val_loss: 2.7539 - val_mean_squared_error: 2.7539
# Epoch 42/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.3594 - mean_squared_error: 2.3594 - val_loss: 2.7791 - val_mean_squared_error: 2.7791
# Epoch 43/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.3946 - mean_squared_error: 2.3946 - val_loss: 2.7359 - val_mean_squared_error: 2.7359
# Epoch 44/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.3390 - mean_squared_error: 2.3390 - val_loss: 2.7183 - val_mean_squared_error: 2.7183
# Epoch 45/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.3609 - mean_squared_error: 2.3609 - val_loss: 2.8184 - val_mean_squared_error: 2.8184
# Epoch 46/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.2958 - mean_squared_error: 2.2958 - val_loss: 2.6904 - val_mean_squared_error: 2.6904
# Epoch 47/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.3207 - mean_squared_error: 2.3207 - val_loss: 2.7054 - val_mean_squared_error: 2.7054
# Epoch 48/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.2581 - mean_squared_error: 2.2581 - val_loss: 2.6883 - val_mean_squared_error: 2.6883
# Epoch 49/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.2272 - mean_squared_error: 2.2272 - val_loss: 2.6705 - val_mean_squared_error: 2.6705
# Epoch 50/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.2898 - mean_squared_error: 2.2898 - val_loss: 2.7056 - val_mean_squared_error: 2.7056
# Epoch 51/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.2522 - mean_squared_error: 2.2522 - val_loss: 2.6729 - val_mean_squared_error: 2.6729
# Epoch 52/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.2329 - mean_squared_error: 2.2329 - val_loss: 2.6411 - val_mean_squared_error: 2.6411
# Epoch 53/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.1771 - mean_squared_error: 2.1771 - val_loss: 2.6684 - val_mean_squared_error: 2.6684
# Epoch 54/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.1541 - mean_squared_error: 2.1541 - val_loss: 2.6473 - val_mean_squared_error: 2.6473
# Epoch 55/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.1039 - mean_squared_error: 2.1039 - val_loss: 2.6226 - val_mean_squared_error: 2.6226
# Epoch 56/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.0916 - mean_squared_error: 2.0916 - val_loss: 2.6191 - val_mean_squared_error: 2.6191
# Epoch 57/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.0726 - mean_squared_error: 2.0726 - val_loss: 2.6178 - val_mean_squared_error: 2.6178
# Epoch 58/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.1598 - mean_squared_error: 2.1598 - val_loss: 2.6708 - val_mean_squared_error: 2.6708
# Epoch 59/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.0434 - mean_squared_error: 2.0434 - val_loss: 2.6609 - val_mean_squared_error: 2.6609
# Epoch 60/60
# 25/25 [==============================] - 42s 2s/step - loss: 2.0587 - mean_squared_error: 2.0587 - val_loss: 2.6325 - val_mean_squared_error: 2.6325

# %%
pred = model.predict([val_encodings.input_ids, val_encodings.token_type_ids, val_encodings.attention_mask,
                      val_one_hot_data['Auth_country'], val_one_hot_data['Pub_country'], val_one_hot_data['Funding'],
                      val_num_data])
# Out:
# 43/43 [==============================] - 15s 289ms/step

# %%
predictions = pred.reshape((-1))
fig, ax = plt.subplots()
ax.hist2d(predictions, y_val , bins=(np.arange(0, 14, 0.2), np.arange(0, 14, 0.2)))
ax.set_title('sciBERT with small metadata')
ax.set_xlabel('Predicted')
ax.set_ylabel('Observed')
# Out:
# Text(0, 0.5, 'Observed')

# %%
np.corrcoef(predictions, y_val)
# Out:
# array([[1.        , 0.68510767],
#        [0.68510767, 1.        ]])

# %%
df_to_save = pd.DataFrame({'Observed':y_val, 'Predicted':predictions})
p = os.path.abspath('.')
file_path = os.path.join(p, 'results_csv', 'scibert_title_smallmeta.csv')
df_to_save.to_csv(file_path, sep = '\t')
